# %%
import httpx

print(httpx.__version__)

# %%
app_key = input("Your app key")
app_secret = input("Your app secret")

# %%
from aioSchwab.client import Client

client = Client(app_key, app_secret)
print(client.account_linked().json())  # make api calls
